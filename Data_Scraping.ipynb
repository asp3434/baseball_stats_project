# %%
# import libraries
import requests
from bs4 import BeautifulSoup
import re
import time
import pandas as pd

# %% [markdown]
# ## Data Acquisition
# www.baseball-reference.com only allows 20 requests per minute. If we violate this rule, our session will be locked out for one hour.

# %% [markdown]
# ### Web Crawling and Scraping - World Series Winners and Runners Up

# %%
main_url = 'https://www.baseball-reference.com'
world_series_url = 'https://www.baseball-reference.com/postseason/world-series.shtml'
ws_url_page = requests.get(world_series_url)
ws_soup = BeautifulSoup(ws_url_page.content)

# %%
table = ws_soup.find_all('table', {'id': 'world_series_winners_al_nl'})

world_series_winner_links = []
world_series_ru_links = []
world_series_winner = []
world_series_ru = []
years1 = [f'200{str(i)}' for i in range(0,10)]
years2 = [f'201{str(i)}' for i in range(0,10)]
years3 = [f'202{str(i)}' for i in range(0,3)]
years4 = years1 + years2 + years3
years = [years4[-1-i] for i in range(len(years4))]

for t in table:
    td = t.find_all('td')
    for team in td:
        winner = team.find('strong')
        check1 = team.get('data-stat')
        if winner == None:
            if (check1 == 'al_winner') or (check1 == 'nl_winner'):
                try:
                    ru_href = team.find('a')['href']
                    world_series_ru_links.append(str(ru_href))
                    ru_string = str(ru_href)
                    world_series_ru.append(ru_string[7:10])
                    if ru_string[11:15] == '2000':
                        break
                except:
                    pass
        else:
            try:
                winner_href = winner.find('a')['href']
                world_series_winner_links.append(str(winner_href))
                winner_string = str(winner_href)
                world_series_winner.append(winner_string[7:10])
            except:
                pass

# %%
print(len(world_series_ru))
print(len(world_series_winner))
print(world_series_winner)
print(world_series_ru)
print(len(years))
print(years)

temp1 = ['PHI', 'TBD', 'DET', 'DET', 'ARI', 'KCR','KCR','TBD','WSN','PIT','PIT','MIN','HOU','HOU','ARI','PHI','MIN','DET','KCR','DET','PIT','BAL','OAK']
temp2 = ['CHC', 'PIT', 'TBD', 'TBD', 'KCR', 'PIT','TBD','PIT','SEA','WSN','SEA','HOU','CHC','MIA','COL','CIN','CIN','SFG','BAL','BAL','TEX','ARI','WSN']
worst_teams1 = [temp1[-1-i] for i in range(len(temp1))]
worst_teams2 = [temp2[-1-i] for i in range(len(temp2))]
mid_teams1 =   ['CHW','PHI','HOU','CHC','WSN','TBR','NYY','CLE','MIL','NYY','MIL','WSN','OAK','TBR','LAD','TOR','CIN','MIL','CHW','STL','PHI','BOS','ANA']
mid_teams2 =   ['SFG','CLE','SFG','PHI','ARI','TEX','KCR','BAL','NYM','ARI','ARI','CLE','DET','CHC','ARI','LAD','TEX','WSN','FLA','ARI','FLA','NYM','COL']
print(worst_teams1)
print(worst_teams2)
print(mid_teams1)
print(mid_teams2)
# Out:
# 23
# 23
# ['HOU', 'ATL', 'LAD', 'WSN', 'BOS', 'HOU', 'CHC', 'KCR', 'SFG', 'BOS', 'SFG', 'STL', 'SFG', 'NYY', 'PHI', 'BOS', 'STL', 'CHW', 'BOS', 'FLA', 'ANA', 'ARI', 'NYY']
# ['PHI', 'HOU', 'TBR', 'HOU', 'LAD', 'LAD', 'CLE', 'NYM', 'KCR', 'STL', 'DET', 'TEX', 'TEX', 'PHI', 'TBR', 'COL', 'DET', 'HOU', 'STL', 'NYY', 'SFG', 'NYY', 'NYM']
# 23
# ['2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000']
# ['OAK', 'BAL', 'PIT', 'DET', 'KCR', 'DET', 'MIN', 'PHI', 'ARI', 'HOU', 'HOU', 'MIN', 'PIT', 'PIT', 'WSN', 'TBD', 'KCR', 'KCR', 'ARI', 'DET', 'DET', 'TBD', 'PHI']
# ['WSN', 'ARI', 'TEX', 'BAL', 'BAL', 'SFG', 'CIN', 'CIN', 'COL', 'MIA', 'CHC', 'HOU', 'SEA', 'WSN', 'SEA', 'PIT', 'TBD', 'PIT', 'KCR', 'TBD', 'TBD', 'PIT', 'CHC']
# ...

# %%
# get the links to team game logs
win_team_bat_game_logs_links = [f'/teams/tgl.cgi?team={world_series_winner[i]}&t=b&year={years[i]}' for i in range(len(years)) if years[i] !='2020']
win_team_pitch_game_logs_links = [f'/teams/tgl.cgi?team={world_series_winner[i]}&t=p&year={years[i]}' for i in range(len(years)) if years[i] !='2020']
ru_team_bat_game_logs_links = [f'/teams/tgl.cgi?team={world_series_ru[i]}&t=b&year={years[i]}' for i in range(len(years)) if years[i] !='2020']
ru_team_pitch_game_logs_links = [f'/teams/tgl.cgi?team={world_series_ru[i]}&t=p&year={years[i]}' for i in range(len(years)) if years[i] !='2020']

mid_team1_bat_links = [f'/teams/tgl.cgi?team={mid_teams1[i]}&t=b&year={years[i]}' for i in range(len(years)) if years[i] !='2020']
mid_team1_pitch_links = [f'/teams/tgl.cgi?team={mid_teams1[i]}&t=p&year={years[i]}' for i in range(len(years)) if years[i] !='2020']
mid_team2_bat_links = [f'/teams/tgl.cgi?team={mid_teams2[i]}&t=b&year={years[i]}' for i in range(len(years)) if years[i] !='2020']
mid_team2_pitch_links = [f'/teams/tgl.cgi?team={mid_teams2[i]}&t=p&year={years[i]}' for i in range(len(years)) if years[i] !='2020']

worst_team1_bat_links = [f'/teams/tgl.cgi?team={worst_teams1[i]}&t=b&year={years[i]}' for i in range(len(years)) if years[i] !='2020']
worst_team1_pitch_links = [f'/teams/tgl.cgi?team={worst_teams1[i]}&t=p&year={years[i]}' for i in range(len(years)) if years[i] !='2020']
worst_team2_bat_links = [f'/teams/tgl.cgi?team={worst_teams2[i]}&t=b&year={years[i]}' for i in range(len(years)) if years[i] !='2020']
worst_team2_pitch_links = [f'/teams/tgl.cgi?team={worst_teams2[i]}&t=p&year={years[i]}' for i in range(len(years)) if years[i] !='2020']


win_team_batting_dataframes = []
win_team_pitching_dataframes = []
ru_team_batting_dataframes = []
ru_team_pitching_dataframes = []

mid_team1_batting_df = []
mid_team1_pitching_df = []
mid_team2_batting_df = []
mid_team2_pitching_df = []

worst_team1_batting_df = []
worst_team1_pitching_df = []
worst_team2_batting_df = []
worst_team2_pitching_df = []

counter = 0
for i in range(len(years)-1):

    win_team_batting_dataframes.append(pd.read_html(f'{main_url}{win_team_bat_game_logs_links[i]}'))
    counter += 1
    if counter%19 == 0:
        time.sleep(61)
    win_team_pitching_dataframes.append(pd.read_html(f'{main_url}{win_team_pitch_game_logs_links[i]}'))
    counter += 1
    if counter%19 == 0:
        time.sleep(61)  
    ru_team_batting_dataframes.append(pd.read_html(f'{main_url}{ru_team_bat_game_logs_links[i]}'))
    counter += 1
    if counter%19 == 0:
        time.sleep(61)
    ru_team_pitching_dataframes.append(pd.read_html(f'{main_url}{ru_team_pitch_game_logs_links[i]}'))
    counter += 1
    if counter%19 == 0:
        time.sleep(61)
        
    mid_team1_batting_df.append(pd.read_html(f'{main_url}{mid_team1_bat_links[i]}'))
    counter += 1
    if counter%19 == 0:
        time.sleep(61)
    mid_team1_pitching_df.append(pd.read_html(f'{main_url}{mid_team1_pitch_links[i]}'))
    counter += 1
    if counter%19 == 0:
        time.sleep(61)
    mid_team2_batting_df.append(pd.read_html(f'{main_url}{mid_team2_bat_links[i]}'))
    counter += 1
    if counter%19 == 0:
        time.sleep(61)
    mid_team2_pitching_df.append(pd.read_html(f'{main_url}{mid_team2_pitch_links[i]}'))
    counter += 1
    if counter%19 == 0:
        time.sleep(61)
    
    worst_team1_batting_df.append(pd.read_html(f'{main_url}{worst_team1_bat_links[i]}'))
    counter += 1
    if counter%19 == 0:
        time.sleep(61)
    worst_team1_pitching_df.append(pd.read_html(f'{main_url}{worst_team1_pitch_links[i]}'))
    counter += 1
    if counter%19 == 0:
        time.sleep(61)
    worst_team2_batting_df.append(pd.read_html(f'{main_url}{worst_team2_bat_links[i]}'))
    counter += 1
    if counter%19 == 0:
        time.sleep(61)
    worst_team2_pitching_df.append(pd.read_html(f'{main_url}{worst_team2_pitch_links[i]}'))
    counter += 1
    if counter%19 == 0:
        time.sleep(61)

# %% [markdown]
# ### Data Cleaning

# %%
for i in range(len(win_team_batting_dataframes)):
    for j in range(len(win_team_batting_dataframes[i][0]["Rk"])):
        try:
            win_team_batting_dataframes[i][0]['Rk'][j] = pd.to_numeric(win_team_batting_dataframes[i][0]['Rk'][j])
            win_team_pitching_dataframes[i][1]['Rk'][j] = pd.to_numeric(win_team_pitching_dataframes[i][1]['Rk'][j])
        except:
            win_team_batting_dataframes[i][0] = win_team_batting_dataframes[i][0].drop([j])
            win_team_pitching_dataframes[i][1] = win_team_pitching_dataframes[i][1].drop([j])
    for k in range(len(ru_team_batting_dataframes[i][0]["Rk"])):
        try:
            ru_team_batting_dataframes[i][0]["Rk"][k] = pd.to_numeric(ru_team_batting_dataframes[i][0]["Rk"][k])
            ru_team_pitching_dataframes[i][1]["Rk"][k] = pd.to_numeric(ru_team_pitching_dataframes[i][1]["Rk"][k])
        except:
            ru_team_batting_dataframes[i][0] = ru_team_batting_dataframes[i][0].drop([k])   
            ru_team_pitching_dataframes[i][1] = ru_team_pitching_dataframes[i][1].drop([k])
            
    for m in range(len(mid_team1_batting_df[i][0]["Rk"])):
        try:
            mid_team1_batting_df[i][0]["Rk"][m] = pd.to_numeric(mid_team1_batting_df[i][0]["Rk"][m])
            mid_team1_pitching_df[i][1]["Rk"][m] = pd.to_numeric(mid_team1_pitching_df[i][1]["Rk"][m])
        except:
            mid_team1_batting_df[i][0] = mid_team1_batting_df[i][0].drop([m])   
            mid_team1_pitching_df[i][1] = mid_team1_pitching_df[i][1].drop([m])
            
    for n in range(len(mid_team2_batting_df[i][0]["Rk"])):
        try:
            mid_team2_batting_df[i][0]["Rk"][n] = pd.to_numeric(mid_team2_batting_df[i][0]["Rk"][n])
            mid_team2_pitching_df[i][1]["Rk"][n] = pd.to_numeric(mid_team2_pitching_df[i][1]["Rk"][n])
        except:
            mid_team2_batting_df[i][0] = mid_team2_batting_df[i][0].drop([n])   
            mid_team2_pitching_df[i][1] = mid_team2_pitching_df[i][1].drop([n])
            
    for r in range(len(worst_team1_batting_df[i][0]["Rk"])):
        try:
            worst_team1_batting_df[i][0]["Rk"][r] = pd.to_numeric(worst_team1_batting_df[i][0]["Rk"][r])
            worst_team1_pitching_df[i][1]["Rk"][r] = pd.to_numeric(worst_team1_pitching_df[i][1]["Rk"][r])
        except:
            worst_team1_batting_df[i][0] = worst_team1_batting_df[i][0].drop([r])   
            worst_team1_pitching_df[i][1] = worst_team1_pitching_df[i][1].drop([r])
            
    for s in range(len(worst_team2_batting_df[i][0]["Rk"])):
        try:
            worst_team2_batting_df[i][0]["Rk"][s] = pd.to_numeric(worst_team2_batting_df[i][0]["Rk"][s])
            worst_team2_pitching_df[i][1]["Rk"][s] = pd.to_numeric(worst_team2_pitching_df[i][1]["Rk"][s])
        except:
            worst_team2_batting_df[i][0] = worst_team2_batting_df[i][0].drop([s])   
            worst_team2_pitching_df[i][1] = worst_team2_pitching_df[i][1].drop([s])
            
    win_team_batting_dataframes[i][0] = win_team_batting_dataframes[i][0].reset_index().drop('index', axis=1)
    win_team_pitching_dataframes[i][1] = win_team_pitching_dataframes[i][1].reset_index().drop('index', axis=1)
    ru_team_batting_dataframes[i][0] = ru_team_batting_dataframes[i][0].reset_index().drop('index', axis=1)
    ru_team_pitching_dataframes[i][1] = ru_team_pitching_dataframes[i][1].reset_index().drop('index', axis=1)
    
    mid_team1_batting_df[i][0] = mid_team1_batting_df[i][0].reset_index().drop('index', axis=1)
    mid_team1_pitching_df[i][1] = mid_team1_pitching_df[i][1].reset_index().drop('index', axis=1)
    mid_team2_batting_df[i][0] = mid_team2_batting_df[i][0].reset_index().drop('index', axis=1)
    mid_team2_pitching_df[i][1] = mid_team2_pitching_df[i][1].reset_index().drop('index', axis=1)
    
    worst_team1_batting_df[i][0] = worst_team1_batting_df[i][0].reset_index().drop('index', axis=1)
    worst_team1_pitching_df[i][1] = worst_team1_pitching_df[i][1].reset_index().drop('index', axis=1)
    worst_team2_batting_df[i][0] = worst_team2_batting_df[i][0].reset_index().drop('index', axis=1)
    worst_team2_pitching_df[i][1] = worst_team2_pitching_df[i][1].reset_index().drop('index', axis=1)

# %%
for i in range(len(win_team_batting_dataframes)):
    try:
        win_team_batting_dataframes[i][0] = win_team_batting_dataframes[i][0].drop(columns=['level_0', 'Gtm'])
        win_team_pitching_dataframes[i][1] = win_team_pitching_dataframes[i][1].drop(columns=['Gtm', 'Umpire'])
        ru_team_batting_dataframes[i][0] = ru_team_batting_dataframes[i][0].drop(columns=['Gtm'])
        ru_team_pitching_dataframes[i][1] = ru_team_pitching_dataframes[i][1].drop(columns=['Gtm', 'Umpire'])
        
        mid_team1_batting_df[i][0] = mid_team1_batting_df[i][0].drop(columns=['level_0', 'Gtm'])
        mid_team1_pitching_df[i][1] = mid_team1_pitching_df[i][1].drop(columns=['Gtm', 'Umpire'])
        mid_team2_batting_df[i][0] = mid_team2_batting_df[i][0].drop(columns=['Gtm'])
        mid_team2_pitching_df[i][1] = mid_team2_pitching_df[i][1].drop(columns=['Gtm', 'Umpire'])
        
        worst_team1_batting_df[i][0] = worst_team1_batting_df[i][0].drop(columns=['level_0', 'Gtm'])
        worst_team1_pitching_df[i][1] = worst_team1_pitching_df[i][1].drop(columns=['Gtm', 'Umpire'])
        worst_team2_batting_df[i][0] = worst_team2_batting_df[i][0].drop(columns=['Gtm'])
        worst_team2_pitching_df[i][1] = worst_team2_pitching_df[i][1].drop(columns=['Gtm', 'Umpire'])
    except:
        pass
    
    win_team_batting_dataframes[i][0][['PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SH', 'SF', 'ROE', 'GDP', 'SB', 'CS', 'BA', 'OBP', 'SLG', 'OPS', 'LOB', '#']] = win_team_batting_dataframes[i][0][['PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SH', 'SF', 'ROE', 'GDP', 'SB', 'CS', 'BA', 'OBP', 'SLG', 'OPS', 'LOB', '#']].apply(pd.to_numeric)
    win_team_pitching_dataframes[i][1][['Rk', 'IP', 'H', 'R', 'ER', 'UER', 'BB', 'SO', 'HR', 'HBP', 'ERA', 'BF', 'Pit', 'Str', 'IR', 'IS', 'SB', 'CS', 'AB', '2B', '3B', 'IBB', 'SH', 'SF', 'ROE', 'GDP', '#']] = win_team_pitching_dataframes[i][1][['Rk', 'IP', 'H', 'R', 'ER', 'UER', 'BB', 'SO', 'HR', 'HBP', 'ERA', 'BF', 'Pit', 'Str', 'IR', 'IS', 'SB', 'CS', 'AB', '2B', '3B', 'IBB', 'SH', 'SF', 'ROE', 'GDP', '#']].apply(pd.to_numeric)
    ru_team_batting_dataframes[i][0][['PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SH', 'SF', 'ROE', 'GDP', 'SB', 'CS', 'BA', 'OBP', 'SLG', 'OPS', 'LOB', '#']] = ru_team_batting_dataframes[i][0][['PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SH', 'SF', 'ROE', 'GDP', 'SB', 'CS', 'BA', 'OBP', 'SLG', 'OPS', 'LOB', '#']].apply(pd.to_numeric)
    ru_team_pitching_dataframes[i][1][['Rk', 'IP', 'H', 'R', 'ER', 'UER', 'BB', 'SO', 'HR', 'HBP', 'ERA', 'BF', 'Pit', 'Str', 'IR', 'IS', 'SB', 'CS', 'AB', '2B', '3B', 'IBB', 'SH', 'SF', 'ROE', 'GDP', '#']] = ru_team_pitching_dataframes[i][1][['Rk', 'IP', 'H', 'R', 'ER', 'UER', 'BB', 'SO', 'HR', 'HBP', 'ERA', 'BF', 'Pit', 'Str', 'IR', 'IS', 'SB', 'CS', 'AB', '2B', '3B', 'IBB', 'SH', 'SF', 'ROE', 'GDP', '#']].apply(pd.to_numeric)
    
    mid_team1_batting_df[i][0][['PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SH', 'SF', 'ROE', 'GDP', 'SB', 'CS', 'BA', 'OBP', 'SLG', 'OPS', 'LOB', '#']] = mid_team1_batting_df[i][0][['PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SH', 'SF', 'ROE', 'GDP', 'SB', 'CS', 'BA', 'OBP', 'SLG', 'OPS', 'LOB', '#']].apply(pd.to_numeric)
    mid_team1_pitching_df[i][1][['Rk', 'IP', 'H', 'R', 'ER', 'UER', 'BB', 'SO', 'HR', 'HBP', 'ERA', 'BF', 'Pit', 'Str', 'IR', 'IS', 'SB', 'CS', 'AB', '2B', '3B', 'IBB', 'SH', 'SF', 'ROE', 'GDP', '#']] = mid_team1_pitching_df[i][1][['Rk', 'IP', 'H', 'R', 'ER', 'UER', 'BB', 'SO', 'HR', 'HBP', 'ERA', 'BF', 'Pit', 'Str', 'IR', 'IS', 'SB', 'CS', 'AB', '2B', '3B', 'IBB', 'SH', 'SF', 'ROE', 'GDP', '#']].apply(pd.to_numeric)
    mid_team2_batting_df[i][0][['PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SH', 'SF', 'ROE', 'GDP', 'SB', 'CS', 'BA', 'OBP', 'SLG', 'OPS', 'LOB', '#']] = mid_team2_batting_df[i][0][['PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SH', 'SF', 'ROE', 'GDP', 'SB', 'CS', 'BA', 'OBP', 'SLG', 'OPS', 'LOB', '#']].apply(pd.to_numeric)
    mid_team2_pitching_df[i][1][['Rk', 'IP', 'H', 'R', 'ER', 'UER', 'BB', 'SO', 'HR', 'HBP', 'ERA', 'BF', 'Pit', 'Str', 'IR', 'IS', 'SB', 'CS', 'AB', '2B', '3B', 'IBB', 'SH', 'SF', 'ROE', 'GDP', '#']] = mid_team2_pitching_df[i][1][['Rk', 'IP', 'H', 'R', 'ER', 'UER', 'BB', 'SO', 'HR', 'HBP', 'ERA', 'BF', 'Pit', 'Str', 'IR', 'IS', 'SB', 'CS', 'AB', '2B', '3B', 'IBB', 'SH', 'SF', 'ROE', 'GDP', '#']].apply(pd.to_numeric)
    
    worst_team1_batting_df[i][0][['PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SH', 'SF', 'ROE', 'GDP', 'SB', 'CS', 'BA', 'OBP', 'SLG', 'OPS', 'LOB', '#']] = worst_team1_batting_df[i][0][['PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SH', 'SF', 'ROE', 'GDP', 'SB', 'CS', 'BA', 'OBP', 'SLG', 'OPS', 'LOB', '#']].apply(pd.to_numeric)
    worst_team1_pitching_df[i][1][['Rk', 'IP', 'H', 'R', 'ER', 'UER', 'BB', 'SO', 'HR', 'HBP', 'ERA', 'BF', 'Pit', 'Str', 'IR', 'IS', 'SB', 'CS', 'AB', '2B', '3B', 'IBB', 'SH', 'SF', 'ROE', 'GDP', '#']] = worst_team1_pitching_df[i][1][['Rk', 'IP', 'H', 'R', 'ER', 'UER', 'BB', 'SO', 'HR', 'HBP', 'ERA', 'BF', 'Pit', 'Str', 'IR', 'IS', 'SB', 'CS', 'AB', '2B', '3B', 'IBB', 'SH', 'SF', 'ROE', 'GDP', '#']].apply(pd.to_numeric)
    worst_team2_batting_df[i][0][['PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SH', 'SF', 'ROE', 'GDP', 'SB', 'CS', 'BA', 'OBP', 'SLG', 'OPS', 'LOB', '#']] = worst_team2_batting_df[i][0][['PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SH', 'SF', 'ROE', 'GDP', 'SB', 'CS', 'BA', 'OBP', 'SLG', 'OPS', 'LOB', '#']].apply(pd.to_numeric)
    worst_team2_pitching_df[i][1][['Rk', 'IP', 'H', 'R', 'ER', 'UER', 'BB', 'SO', 'HR', 'HBP', 'ERA', 'BF', 'Pit', 'Str', 'IR', 'IS', 'SB', 'CS', 'AB', '2B', '3B', 'IBB', 'SH', 'SF', 'ROE', 'GDP', '#']] = worst_team2_pitching_df[i][1][['Rk', 'IP', 'H', 'R', 'ER', 'UER', 'BB', 'SO', 'HR', 'HBP', 'ERA', 'BF', 'Pit', 'Str', 'IR', 'IS', 'SB', 'CS', 'AB', '2B', '3B', 'IBB', 'SH', 'SF', 'ROE', 'GDP', '#']].apply(pd.to_numeric)

# %% [markdown]
# ### Save Data

# %%
new_years = [years[i] for i in range(len(years)) if i != 2]
new_mid_teams1 = [mid_teams1[i] for i in range(len(mid_teams1)) if i != 2]
new_mid_teams2 = [mid_teams2[i] for i in range(len(mid_teams2)) if i != 2]
new_worst_teams1 = [worst_teams1[i] for i in range(len(worst_teams1)) if i != 2]
new_worst_teams2 = [worst_teams2[i] for i in range(len(worst_teams2)) if i != 2]
new_winning_team = [world_series_winner[i] for i in range(len(world_series_winner)) if i != 2]
new_runner_up_team = [world_series_ru[i] for i in range(len(world_series_ru)) if i != 2]

print(new_years)
print(new_winning_team)
print(new_runner_up_team)
# Out:
# ['2022', '2021', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000']
# ['HOU', 'ATL', 'WSN', 'BOS', 'HOU', 'CHC', 'KCR', 'SFG', 'BOS', 'SFG', 'STL', 'SFG', 'NYY', 'PHI', 'BOS', 'STL', 'CHW', 'BOS', 'FLA', 'ANA', 'ARI', 'NYY']
# ['PHI', 'HOU', 'HOU', 'LAD', 'LAD', 'CLE', 'NYM', 'KCR', 'STL', 'DET', 'TEX', 'TEX', 'PHI', 'TBR', 'COL', 'DET', 'HOU', 'STL', 'NYY', 'SFG', 'NYY', 'NYM']

# %%
for i in range(len(win_team_batting_dataframes)):
    win_team_batting_dataframes[i][0].to_csv(f'winning_team_batting_{new_winning_team[i]}_{new_years[i]}.csv')
    win_team_pitching_dataframes[i][1].to_csv(f'winning_team_pitching_{new_winning_team[i]}_{new_years[i]}.csv')
    
    ru_team_batting_dataframes[i][0].to_csv(f'runn_up_team_batting_{new_runner_up_team[i]}_{new_years[i]}.csv')
    ru_team_pitching_dataframes[i][1].to_csv(f'runn_up_team_pitching_{new_runner_up_team[i]}_{new_years[i]}.csv')
    
    mid_team1_batting_df[i][0].to_csv(f'mid_team1_batting_{new_mid_teams1[i]}_{new_years[i]}.csv')
    mid_team1_pitching_df[i][1].to_csv(f'mid_team1_pitching_{new_mid_teams1[i]}_{new_years[i]}.csv')
    
    mid_team2_batting_df[i][0].to_csv(f'mid_team2_batting_{new_mid_teams2[i]}_{new_years[i]}.csv')
    mid_team2_pitching_df[i][1].to_csv(f'mid_team2_pitching_{new_mid_teams2[i]}_{new_years[i]}.csv')
    
    worst_team1_batting_df[i][0].to_csv(f'worst_team1_batting_{new_worst_teams1[i]}_{new_years[i]}.csv')
    worst_team1_pitching_df[i][1].to_csv(f'worst_team1_pitching_{new_worst_teams1[i]}_{new_years[i]}.csv')
    
    worst_team2_batting_df[i][0].to_csv(f'worst_team2_batting_{new_worst_teams2[i]}_{new_years[i]}.csv')
    worst_team2_pitching_df[i][1].to_csv(f'worst_team2_pitching_{new_worst_teams2[i]}_{new_years[i]}.csv')
